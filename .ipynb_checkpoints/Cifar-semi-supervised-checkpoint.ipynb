# %%
# Check TensorFlow version
import tensorflow as tf
print(tf.__version__) # should be 2.5.0+
import tensorflow_datasets as tfds

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import layers
from timeit import default_timer as timer 
assert tf.test.is_gpu_available()
assert tf.test.is_built_with_cuda()
# Out:
# 2.9.1
# WARNING:tensorflow:From /tmp/ipykernel_29053/2641255016.py:12: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2022-07-31 11:40:14.264602: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-31 11:40:15.194956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /device:GPU:0 with 7376 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
start = np.random.randint(0,40000)
plt.figure(figsize=(10,10))
for j in range(25):
    i = start + j
    plt.subplot(5,5,j+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])
    plt.xlabel(class_names[int(train_labels[i])])
plt.show()
train_images[i].shape
# Out:
# (32, 32, 3)

# %%
import sys
sys.path.append('/home/me.docker/work/semi_supervised/models/')
from resnets import cifar_WRN_28_n, cifar_wide_resnet

# %%
# model = cifar_WRN_28_n(2)
# model.summary()
model = cifar_wide_resnet(28, 2, 'preactivated', shortcut_type='B', dropout=0.5, l2_reg=5e-4)

# %%
BATCH_SIZE = 32
# Create datasets 
train_data = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
test_data = tf.data.Dataset.from_tensor_slices((test_images, test_labels))

# Make datasets faster
train_data = train_data.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_data = test_data.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

train_data, test_data, len(train_data), len(test_data)
# Out:
# 2022-07-31 11:42:54.260401: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1228800000 exceeds 10% of free system memory.
# 2022-07-31 11:42:55.522837: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1228800000 exceeds 10% of free system memory.
# (<PrefetchDataset element_spec=(TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float64, name=None), TensorSpec(shape=(None, 1), dtype=tf.uint8, name=None))>,
#  <PrefetchDataset element_spec=(TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float64, name=None), TensorSpec(shape=(None, 1), dtype=tf.uint8, name=None))>,
#  1563,
#  313)

# %%
# Compile the model
scce = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
logs = dict()
models = dict()
for lr in [1e-3, 1e-2]:
    model = cifar_wide_resnet(28, 2, 'preactivated', shortcut_type='B', dropout=0.2, l2_reg=0)
    model.compile(loss=scce, # since labels aren't one-hot, use sparse_categorical_crossentropy
                  optimizer=tf.keras.optimizers.Adam(lr=lr),
                  metrics=["accuracy"])

    # Fit model 
    logs[lr] = model.fit(train_data,
                        epochs=30,
                        steps_per_epoch=len(train_data),
                        validation_data=test_data,
                        validation_steps=len(test_data))
    models[lr] = model
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 34s 19ms/step - loss: 1.3096 - accuracy: 0.5234 - val_loss: 1.1804 - val_accuracy: 0.5932
# Epoch 2/30
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.8797 - accuracy: 0.6904 - val_loss: 1.2408 - val_accuracy: 0.6092
# Epoch 3/30
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.6988 - accuracy: 0.7564 - val_loss: 1.0287 - val_accuracy: 0.6795
# Epoch 4/30
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.5885 - accuracy: 0.7960 - val_loss: 0.7247 - val_accuracy: 0.7637
# Epoch 5/30
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.5077 - accuracy: 0.8245 - val_loss: 0.7185 - val_accuracy: 0.7644
# Epoch 6/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.4445 - accuracy: 0.8468 - val_loss: 0.6807 - val_accuracy: 0.7819
# Epoch 7/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.3934 - accuracy: 0.8623 - val_loss: 0.7716 - val_accuracy: 0.7704
# Epoch 8/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.3467 - accuracy: 0.8790 - val_loss: 0.6786 - val_accuracy: 0.7999
# Epoch 9/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.3109 - accuracy: 0.8909 - val_loss: 0.7799 - val_accuracy: 0.7811
# Epoch 10/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.2733 - accuracy: 0.9042 - val_loss: 0.7146 - val_accuracy: 0.8046
# Epoch 11/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.2476 - accuracy: 0.9116 - val_loss: 0.7395 - val_accuracy: 0.7961
# Epoch 12/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.2202 - accuracy: 0.9210 - val_loss: 0.7483 - val_accuracy: 0.8114
# Epoch 13/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1969 - accuracy: 0.9298 - val_loss: 0.7504 - val_accuracy: 0.8062
# Epoch 14/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1821 - accuracy: 0.9350 - val_loss: 0.6661 - val_accuracy: 0.8358
# Epoch 15/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1618 - accuracy: 0.9424 - val_loss: 0.9087 - val_accuracy: 0.8021
# Epoch 16/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1529 - accuracy: 0.9451 - val_loss: 0.7738 - val_accuracy: 0.8200
# Epoch 17/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1352 - accuracy: 0.9507 - val_loss: 0.7868 - val_accuracy: 0.8276
# Epoch 18/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1271 - accuracy: 0.9549 - val_loss: 0.7749 - val_accuracy: 0.8287
# Epoch 19/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1172 - accuracy: 0.9578 - val_loss: 0.8100 - val_accuracy: 0.8350
# Epoch 20/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1087 - accuracy: 0.9609 - val_loss: 0.7827 - val_accuracy: 0.8430
# Epoch 21/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0995 - accuracy: 0.9643 - val_loss: 1.0513 - val_accuracy: 0.7885
# Epoch 22/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1023 - accuracy: 0.9640 - val_loss: 0.7303 - val_accuracy: 0.8428
# Epoch 23/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0912 - accuracy: 0.9672 - val_loss: 0.7736 - val_accuracy: 0.8437
# Epoch 24/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0868 - accuracy: 0.9677 - val_loss: 0.9206 - val_accuracy: 0.8152
# Epoch 25/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0784 - accuracy: 0.9715 - val_loss: 0.9305 - val_accuracy: 0.8259
# Epoch 26/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0777 - accuracy: 0.9721 - val_loss: 0.7900 - val_accuracy: 0.8447
# Epoch 27/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0764 - accuracy: 0.9735 - val_loss: 0.8908 - val_accuracy: 0.8308
# Epoch 28/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0695 - accuracy: 0.9752 - val_loss: 0.7688 - val_accuracy: 0.8515
# Epoch 29/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0669 - accuracy: 0.9767 - val_loss: 0.8897 - val_accuracy: 0.8380
# Epoch 30/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0661 - accuracy: 0.9772 - val_loss: 0.8156 - val_accuracy: 0.8443
# Epoch 1/30
# 1563/1563 [==============================] - 36s 20ms/step - loss: 1.5347 - accuracy: 0.4288 - val_loss: 1.3910 - val_accuracy: 0.5463
# Epoch 2/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.0285 - accuracy: 0.6319 - val_loss: 1.1971 - val_accuracy: 0.5976
# Epoch 3/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.8178 - accuracy: 0.7123 - val_loss: 0.8553 - val_accuracy: 0.7157
# Epoch 4/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.6677 - accuracy: 0.7675 - val_loss: 0.7910 - val_accuracy: 0.7268
# Epoch 5/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.5627 - accuracy: 0.8052 - val_loss: 0.8015 - val_accuracy: 0.7415
# Epoch 6/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.4855 - accuracy: 0.8308 - val_loss: 0.8022 - val_accuracy: 0.7455
# Epoch 7/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.4202 - accuracy: 0.8543 - val_loss: 0.6588 - val_accuracy: 0.7923
# Epoch 8/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.3671 - accuracy: 0.8708 - val_loss: 0.7824 - val_accuracy: 0.7836
# Epoch 9/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.3189 - accuracy: 0.8879 - val_loss: 0.8666 - val_accuracy: 0.7664
# Epoch 10/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.2777 - accuracy: 0.9025 - val_loss: 0.8448 - val_accuracy: 0.7749
# Epoch 11/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.2468 - accuracy: 0.9101 - val_loss: 0.7622 - val_accuracy: 0.7994
# Epoch 12/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.2153 - accuracy: 0.9231 - val_loss: 0.7063 - val_accuracy: 0.8236
# Epoch 13/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1946 - accuracy: 0.9301 - val_loss: 0.7297 - val_accuracy: 0.8233
# Epoch 14/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1797 - accuracy: 0.9349 - val_loss: 0.7513 - val_accuracy: 0.8191
# Epoch 15/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1591 - accuracy: 0.9434 - val_loss: 0.6834 - val_accuracy: 0.8261
# Epoch 16/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1467 - accuracy: 0.9471 - val_loss: 0.7847 - val_accuracy: 0.8149
# Epoch 17/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1356 - accuracy: 0.9505 - val_loss: 0.9274 - val_accuracy: 0.8075
# Epoch 18/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1266 - accuracy: 0.9535 - val_loss: 0.9948 - val_accuracy: 0.8085
# Epoch 19/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1171 - accuracy: 0.9577 - val_loss: 0.8934 - val_accuracy: 0.8202
# Epoch 20/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1078 - accuracy: 0.9608 - val_loss: 0.6934 - val_accuracy: 0.8428
# Epoch 21/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.1058 - accuracy: 0.9620 - val_loss: 0.8956 - val_accuracy: 0.8243
# Epoch 22/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0957 - accuracy: 0.9659 - val_loss: 0.8223 - val_accuracy: 0.8354
# Epoch 23/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0953 - accuracy: 0.9661 - val_loss: 0.7833 - val_accuracy: 0.8477
# Epoch 24/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0874 - accuracy: 0.9691 - val_loss: 0.7840 - val_accuracy: 0.8496
# Epoch 25/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0822 - accuracy: 0.9710 - val_loss: 1.0269 - val_accuracy: 0.8204
# Epoch 26/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0814 - accuracy: 0.9710 - val_loss: 0.8900 - val_accuracy: 0.8401
# Epoch 27/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0777 - accuracy: 0.9735 - val_loss: 1.0333 - val_accuracy: 0.8064
# Epoch 28/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0740 - accuracy: 0.9742 - val_loss: 0.9334 - val_accuracy: 0.8425
# Epoch 29/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0697 - accuracy: 0.9758 - val_loss: 0.8177 - val_accuracy: 0.8481
# Epoch 30/30
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.0704 - accuracy: 0.9752 - val_loss: 0.9661 - val_accuracy: 0.8379

# %%
# history.history.keys()
plt.figure()
colors = ['r', 'g', 'b', 'k', 'p']
for lr, c  in zip(logs, colors[len(logs)]):
    plt.plot(logs[lr].history['val_accuracy'], color=c, label=lr)
    plt.plot(logs[lr].history['accuracy'], color=c, linestyle='--')
plt.grid()
plt.legend()
